# %%
import pandas as pd

# لعرض كل الأعمدة بدون إخفاء
pd.set_option('display.max_columns', None)

# لعرض محتوى الخلية بالكامل (لو النص طويل)
pd.set_option('display.max_colwidth', None)

# لزيادة عرض الشاشة عشان البيانات ما تنزلش في سطر جديد
pd.set_option('display.width', 2000) 

# كود القراءة بتاعك
# df = pd.read_excel('file_path.xlsx')
# print(df.head())

# %%
import pandas as pd

# %%
file_path = '1.xlsx'

# قراءة الملف
df = pd.read_excel(file_path)

# عرض أول 5 صفوف للتأكد من قراءة البيانات بشكل صحيح
print(df)
# Out:
#                 Unnamed: 0                                                     Yellow                                                                                                                                                                         Performance Notice.      Unnamed: 3                                                                                                 Unnamed: 4     Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8 Unnamed: 9    Unnamed: 10 Unnamed: 11    Unnamed: 12
# ...

# %%
import pandas as pd

data = {
    "Category": [
        "Attendance & adherance", "Attendance & adherance", "Attendance & adherance", "Attendance & adherance", "Attendance & adherance", "Attendance & adherance", "Attendance & adherance",
        "Personal Attitude", "Personal Attitude", "Personal Attitude", "Personal Attitude",
        "Abusing", "Abusing", "Abusing", "Abusing", "Abusing",
        "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy", "Policy"
    ],
    "Incident": [
        "Late Arrival", "No-show", "Exceed breaks", "Un-scheduled breaks", "Out of working hours attendance", "Attendance manipulation", "Early leave",
        "Use of abusive words", "Physical harm", "Sleeping on the floor", "Unprofessional behavior",
        "Company assets", "Routing calls / tickets", "Releasing calls / tickets", "Using other colleague's logins", "Aux system reports & tools",
        "Medical examination", "Visitors", "Smoking", "Influence of Alcohol / drugs", "Harassment", "Stealing", "Social media", "Data confidentiality, ethical conduct, and damage control", "Mobile phones", "Food & beverage", "Business process failure", "End-user critical failure", "Cyber security", "Unprofessional behaviorss"
    ],
    "Details": [
        "Arriving late to work.", 
        "Missing a scheduled shift without notification.", 
        "Taking longer breaks than allowed.", 
        "Taking breaks at unauthorized times.", 
        "Staying in the workplace after finishing the shift.", 
        "Faking attendance records.", 
        "Leaving work early without approval.",
        "Using offensive or disrespectful language.", 
        "Causing physical harm to another person.", 
        "Sleeping in the workplace during working hours.", 
        "Behaving in a way that is not appropriate for the workplace.",
        "Damaging or misusing company property.", 
        "Avoiding or redirecting assigned work.", 
        "Closing assigned work without completing it.", 
        "Sharing or using another employee's login credentials.", 
        "Misusing auxiliary systems or tools.",
        "Refusing to undergo a required medical examination.", 
        "Meeting visitors outside of designated areas.", 
        "Smoking in prohibited areas.", 
        "Being under the influence of alcohol or drugs at work.", 
        "Engaging in harassing behavior towards another person.", 
        "Taking company property without permission.", 
        "Misusing social media in a way that reflects poorly on the company.", 
        "Unauthorized data sharing, unethical behavior, and actions causing potential contract loss or reputational damage.", 
        "Using personal mobile phones or computers for non-work purposes during working hours.", 
        "Eating or drinking in prohibited areas.", 
        "Repeated or severe Business process violation that is critical to business.", 
        "Repeated or severe Business process violation that is critical to End-user such as payouts and attitude issues with customers.", 
        "- Downloading unauthorized applications, movies, or files.\n- Bypassing security measures to access restricted content.\n- Sharing unauthorized applications or links with other employees.", 
        ""
    ],
    "Within (Days)": [
        30, 90, 30, 30, 90, 180, 180,
        180, 180, 180, 180,
        180, 180, 180, 180, 30,
        180, 180, 180, 180, 180, 180, 180, 180, 30, 30, 30, 60, 30, 0
    ],
    "Comments": [
        "Time deduction + action\naligning with the manager is necessary or the action escalates to the next level", "", "", "", "", "", "",
        "", "", "", "",
        "", "", "", "", "",
        "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ],
    "1st time": [
        "Yellow", "Red", "Yellow", "Yellow", "Yellow", "Black", "Black",
        "Black", "Investigation", "Black", "Black",
        "Investigation", "Black", "Investigation", "Investigation", "Yellow",
        "Investigation", "Black", "Black", "Investigation", "Investigation", "Investigation", "Investigation", "Investigation", "Red", "Orange", "Orange", "Black", "Red", "Orange"
    ],
    "2nd time": [
        "Yellow", "Red", "Yellow", "Red", "Red", "Investigation", "Investigation",
        "Investigation", "", "Investigation", "Investigation",
        "", "Investigation", "", "", "Yellow",
        "", "Investigation", "Investigation", "", "", "", "", "", "Black", "Red", "Red", "Investigation", "Black", "Black"
    ],
    "3rd time": [
        "Orange", "Black", "Yellow", "Black", "Black", "", "",
        "", "", "", "",
        "", "", "", "", "Orange",
        "", "", "", "", "", "", "", "", "Investigation", "Black", "Black", "", "Investigation", "Investigation"
    ],
    "4th time": [
        "Red", "Investigation", "Yellow", "Investigation", "Investigation", "", "",
        "", "", "", "",
        "", "", "", "", "Red",
        "", "", "", "", "", "", "", "", "", "Investigation", "Investigation", "", "", ""
    ],
    "5th time": [
        "Black", "", "Orange", "", "", "", "",
        "", "", "", "",
        "", "", "", "", "Black",
        "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ],
    "6th time": [
        "Investigation", "", "Red", "", "", "", "",
        "", "", "", "",
        "", "", "", "", "Investigation",
        "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ],
    "7th time": [
        "", "", "Black", "", "", "", "",
        "", "", "", "",
        "", "", "", "", "",
        "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ],
    "8th time": [
        "", "", "Investigation", "", "", "", "",
        "", "", "", "",
        "", "", "", "", "",
        "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ]
}

df = pd.DataFrame(data)
df.to_excel("matrix.xlsx", index=False)
print("✅ تم إنشاء ملف matrix.xlsx بالبيانات المطابقة للنص الأصلي 100%.")
# Out:
# ✅ تم إنشاء ملف matrix.xlsx بالبيانات المطابقة للنص الأصلي 100%.
